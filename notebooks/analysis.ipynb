# %%
import pandas as pd

# %%
DATA = '../data/music_dataset.csv'

# %%
df = pd.read_csv(DATA)

# %%
df
# Out:
#     id      country         style                artist  \
# 0    2       Brazil         Samba               Cartola
# 1    3       Brazil  Funk carioca          MC Bin Laden
# 2    4        India     Bollywood          Arijit Singh
# 3    5        Japan      City Pop       Mariya Takeuchi
# 4    6          USA         Blues             B.B. King
# 5    7  West Africa      Afrobeat             Fela Kuti
# 6    8       Brazil         Samba        Zeca Pagodinho
# 7    9       Brazil    Bossa Nova         João Gilberto
# 8   10       Brazil     Sertanejo  Chitãozinho & Xororó
# 9   11       Brazil      Chorinho           Pixinguinha
# 10  12        India     Classical          Ravi Shankar
# 11  13        India        Bhajan           Anup Jalota
# 12  14        Japan         J-Pop          Hikaru Utada
# 13  15        Japan        Min'yō               Various
# 14  16          USA          Jazz           Miles Davis
# 15  17          USA          Soul       Aretha Franklin
# ...
