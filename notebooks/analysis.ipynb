# %%
import pandas as pd

# %%
DATA = '../data/raw_subsets/subset_metadata.csv'

# %%
df = pd.read_csv(DATA)

# %%
df
# Out:
#         country     style             artist                track_title  link  \
# 0        Brazil     Samba            Cartola         As Rosas Não Falam   NaN
# 1        Brazil     Samba     Zeca Pagodinho      Deixa a Vida Me Levar   NaN
# 2        Brazil     Samba      Beth Carvalho            Coisinha do Pai   NaN
# 3        Brazil     Samba  Paulinho da Viola           Dança da Solidão   NaN
# 4        Brazil     Samba   Martinho da Vila  Canta, Canta, Minha Gente   NaN
# ..          ...       ...                ...                        ...   ...
# 85  West Africa  Afrobeat    Afrobeat Makers              Kalakuta Girl   NaN
# 86  West Africa  Afrobeat     Awilo Longomba                   Karolina   NaN
# 87  West Africa  Afrobeat            Osibisa                     Woyaya   NaN
# 88  West Africa  Afrobeat              Nneka                  Heartbeat   NaN
# 89  West Africa  Afrobeat     Thomas Mapfumo                     Shumba   NaN
#
#      source   license  notes
# ...

# %%
df = df.drop(columns="id")

# %%
df
# Out:
#         country     style             artist                track_title  link  \
# 0        Brazil     Samba            Cartola         As Rosas Não Falam   NaN
# 1        Brazil     Samba     Zeca Pagodinho      Deixa a Vida Me Levar   NaN
# 2        Brazil     Samba      Beth Carvalho            Coisinha do Pai   NaN
# 3        Brazil     Samba  Paulinho da Viola           Dança da Solidão   NaN
# 4        Brazil     Samba   Martinho da Vila  Canta, Canta, Minha Gente   NaN
# ..          ...       ...                ...                        ...   ...
# 85  West Africa  Afrobeat    Afrobeat Makers              Kalakuta Girl   NaN
# 86  West Africa  Afrobeat     Awilo Longomba                   Karolina   NaN
# 87  West Africa  Afrobeat            Osibisa                     Woyaya   NaN
# 88  West Africa  Afrobeat              Nneka                  Heartbeat   NaN
# 89  West Africa  Afrobeat     Thomas Mapfumo                     Shumba   NaN
#
#      source   license  notes
# ...

# %%
df.to_csv(DATA)
